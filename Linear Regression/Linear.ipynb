# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd #Data Manipulation
import numpy as np #Numerical Operation
import matplotlib.pyplot as plt #Data Visualization
from sklearn.linear_model import LinearRegression #Data Modeling

# %% [markdown]
# ## 2. Generating Random Data:

# %%
num_points = 50

X = np.random.randint(0,100,num_points)
Y = 2 * X + np.random.normal(0,10,num_points)

# %% [markdown]
# 3. Creating DataFrame and Saving to CSV

# %%
data = pd.DataFrame({'X':X,'Y':Y})

data.to_csv('data.csv',index=False)

print(data.head(15))
# Out:
#      X           Y
# 0   22   61.160156
# 1   87  170.078803
# 2   77  151.251688
# 3   34   65.862352
# 4    0  -25.232568
# 5   52  108.633669
# 6   65  122.499092
# 7   34   85.353445
# 8    1   12.990107
# 9   38   84.393695
# 10  54  114.931749
# 11  47   91.088000
# 12  32   53.430421
# 13  78  157.609624
# 14  22   50.258607

# %% [markdown]
# 4. Visualizing the Data

# %%
plt.scatter(data['X'],data['Y'])
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title('Scatter Plot of Data by cel')
plt.show()

# %% [markdown]
# 5. Preparing Data for Modeling

# %%
X = data[['X']] #Independent Varia
Y = data[['Y']] #DEpendent vARIA

# %% [markdown]
# 6. Fitting the Linear Regression Model

# %%
model = LinearRegression()

model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# 7. Getting model Coefficients

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)
# Out:
# Slope [2.00051701]
# Intercept [-0.24665277]

# %% [markdown]
# 8. Visualizing the Linear Regression Line

# %%
plt.scatter(X,Y)
plt.plot(X,model.predict(X), color='blue')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title('Linear Regression sheeshhhh')
plt.show()

# %% [markdown]
# 9. Making Prediction

# %%
new_X = [[np.random.randint(100,200)]]

predicted_Y = model.predict(new_X)

print('Value of X: ',new_X)
print('Predictable Value of Y: ',predicted_Y)
# Out:
# Value of X:  [[121]]
# Predictable Value of Y:  [[241.81590488]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
